# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
# Out:
# [transformers] PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
model = ChatOllama(model="gpt-oss:120b-cloud")

prompt1 = PromptTemplate(
    template="generate detailed report on a topic{topic}",
    input_variables= ['topic']
)

prompt2 = PromptTemplate(
    template="generate a 3 point summary of the following text {text}",
    input_variables=['text']
)

parser = StrOutputParser()

chain = prompt1|model|parser|prompt2|model|parser

response = chain.invoke({"topic":"Aliens"})
print(response)
# Out:
# **Three‑point summary**
#
# 1. **Scientific Landscape:**
#    - Astrobiology has identified many habitable environments—from subsurface oceans on icy moons to temperate exoplanets in the circumstellar “habitable zone.” Over 7,000 exoplanets are confirmed, with 30‑50 Earth‑size planets residing in liquid‑water zones, and advanced spectroscopy (JWST, ELTs) is now capable of probing atmospheric biosignatures. SETI, augmented by machine‑learning and broad‑band radio/optical searches, has yet to verify a technosignature but continues expanding the detection parameter space.
#
# 2. **Cultural, Ethical & Policy Dimensions:**
#    - Popular depictions of “aliens” shape public perception and drive support for space research, while raising ethical questions about planetary protection, the rights of potential extraterrestrial life, and the propriety of messaging (METI). Existing space law (Outer Space Treaty, COPUOS guidelines) lacks explicit protocols for confirming extraterrestrial life, prompting ongoing work on an international detection/verification framework.
#
# 3. **Future Imperatives:**
#    - The next decade offers the highest probability yet of discovering microbial life (estimates > 30 % for Mars, Europa, Enceladus) and of detecting biosignatures on exoplanets. To capitalize on this, the report urges (i) unified biosignature‑technosignature funding, (ii) rapid adoption of a global “Protocol for the Detection of Extraterrestrial Life,” and (iii) continued investment in emerging technologies—large interferometric telescopes, space‑based nulling interferometers, AI‑driven data analysis, and in‑situ mini‑laboratories.
