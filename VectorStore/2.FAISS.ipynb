# %%
#FAISS = Facebook AI similarity Search
#built for fast,scalable,similarity search over millions of high dimensional vectors

#FAISS is commonly used when datasets are huge and you need fine-grained control over indexing and retrieval performance

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from dotenv import load_dotenv
load_dotenv()

# %%
cricket_texts = [
    "Cricket is one of the most popular sports in the world."
    "Virat Kohli is known for his excellent batting skills."
    "A cricket match is played between two teams of eleven players each."
    "The bowler tries to dismiss the batsman by hitting the wickets."
    "The Indian cricket team has won multiple international tournaments."
    "Many fans enjoy watching exciting cricket matches in stadiums."
]

embedding = HuggingFaceEmbeddings(
    model_name ="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = FAISS.from_texts(
    texts= cricket_texts,
    embedding= embedding
)

query = "Who is known for the batting skills"
results= vectorstore.similarity_search(query,k=1)
