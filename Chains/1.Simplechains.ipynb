# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
# Out:
# [transformers] PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
model = ChatOllama(model="gpt-oss:120b-cloud")

prompt = PromptTemplate(
    template="generate 3 facts about a topic {topic}",
    input_variables=['topic']
)

parser = StrOutputParser()

chain = prompt|model|parser

response = chain.invoke({"topic":"aliens"})

print(response)
# Out:
# **Three intriguing facts about extraterrestrials (aliens):**
#
# 1. **The Drake Equation** – Formulated in 1961 by astronomer Frank Drake, this equation estimates the number of active, communicative civilizations in our galaxy. While the exact values are uncertain, the equation highlights key factors (star formation rate, fraction of stars with planets, habitability, etc.) that scientists use to gauge how many alien societies might exist.
#
# 2. **Extremophiles on Earth expand the “habitable zone”** – Microorganisms that thrive in extreme environments—such as deep‑sea hydrothermal vents, acidic hot springs, and sub‑zero ice—show that life can survive far beyond the “Goldilocks” conditions once thought necessary. This widens the range of planetary environments (e.g., icy moons like Europa or Titan) where alien life could potentially arise.
#
# 3. **The “Wow! Signal” remains unexplained** – In 1977, Ohio State’s Big Ear radio telescope recorded a brief, strong narrow‑band radio burst from space (catalogued as “6EQUJ5”). The signal lasted only 72 seconds and never repeated, sparking decades of speculation about whether it was a natural astrophysical phenomenon or a possible transmission from an extraterrestrial intelligence.
