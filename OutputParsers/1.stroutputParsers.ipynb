# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

# %%
model = ChatOllama(model="gpt-oss:120b-cloud")
#1st prompt template9
template1 = PromptTemplate(template="write a detailedreport on a {topic}",
                           input_variables=['topic'])

#2nd prompt template
template2 = PromptTemplate(
    template="Write a 5 line summary on the following {text}",
    input_variables=['text']
)

parser = StrOutputParser()
chain = template1 | model |parser | template2 | model |parser

response = chain.invoke({"topic":"Black hole"})
print(response)
# Out:
# **Black Holes – From Theory to Observation and Future Frontiers**
#
# 1. Black holes, predicted by General Relativity and confirmed through X‑ray binaries, gravitational‑wave detections (GW150914 onward), and the first horizon‑scale images (EHT, 2019).
# 2. Three astrophysical families dominate: stellar‑mass (∼3–100 M☉), supermassive (10⁶–10¹⁰ M☉), and the elusive intermediate‑mass (10²–10⁵ M☉) that bridge the mass gap.
# 3. Recent breakthroughs—LIGO/Virgo/KAGRA GW catalogs, ngEHT imaging, and multi‑messenger campaigns—now allow precise measurements of mass, spin, and accretion physics, testing General Relativity in the strong‑field regime.
# 4. Open challenges include the spin evolution of SMBHs, the existence and detection of IMBHs and primordial black holes, and reconciling Hawking radiation with the information paradox.
# 5. Future progress hinges on next‑generation facilities (LISA, Cosmic Explorer, Athena/ Lynx, ngEHT, SKA) and coordinated multi‑messenger strategies to probe black‑hole growth, feedback, and quantum gravity.
