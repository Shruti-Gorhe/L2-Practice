# %%
pip install -U langchain-ollama
# Out:
# ...
#   Using cached langchain_ollama-1.1.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached langchain_ollama-1.1.0-py3-none-any.whl (31 kB)
# Using cached ollama-0.6.2-py3-none-any.whl (15 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_ollama import ChatOllama
from typing import TypedDict

# %%
model = ChatOllama(model="gpt-oss-cloud-120b")
#schema
class Review(TypedDict):
    summary: str
    sentiment: int
    
prompt = """
The hardware is great,but the software feels bloated.
There are too many pre-installed apps that I never use and can't uninstall.
The battery life is decent,but it could be better.
Also the UI looks outdated compared to other brands.
Hoping for software updates to improve the overall experience.Overall,it's a decent device but has room for improvement.
"""

response = model.invoke(prompt, response_schema=Review)
print(response.content)
