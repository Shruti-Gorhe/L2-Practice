# %%
# !pip install -U langchain-google-genai
# Out:
# Collecting langchain-google-genai
#   Using cached langchain_google_genai-4.2.7-py3-none-any.whl.metadata (2.7 kB)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<3.0.0,>=1.65.0 (from langchain-google-genai)
#   Using cached google_genai-2.12.1-py3-none-any.whl.metadata (55 kB)
# Collecting langchain-core<2.0.0,>=1.4.7 (from langchain-google-genai)
#   Using cached langchain_core-1.4.9-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from langchain-google-genai) (2.12.5)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth<2.56.0,>=2.48.1 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.49.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.33.0)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<17.0,>=13.0.0 (from google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Using cached websockets-16.1.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Collecting distro<2,>=1.7.0 (from google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting sniffio (from google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached langsmith-0.10.6-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (26.0)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached uuid_utils-0.17.0-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (46.0.5)
# Requirement already satisfied: certifi in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting orjson>=3.9.14 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached orjson-3.11.9-cp313-cp313-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting xxhash>=3.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached xxhash-3.8.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai)
#   Using cached zstandard-0.25.0-cp313-cp313-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=38.0.3->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Requirement already satisfied: pycparser in c:\users\shrut\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.0)
# Using cached langchain_google_genai-4.2.7-py3-none-any.whl (70 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Using cached google_genai-2.12.1-py3-none-any.whl (1.0 MB)
# Using cached langchain_core-1.4.9-py3-none-any.whl (558 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Using cached langsmith-0.10.6-py3-none-any.whl (661 kB)
# Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached uuid_utils-0.17.0-cp313-cp313-win_amd64.whl (173 kB)
# Downloading websockets-16.1.1-cp313-cp313-win_amd64.whl (180 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Using cached orjson-3.11.9-cp313-cp313-win_amd64.whl (127 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached xxhash-3.8.1-cp313-cp313-win_amd64.whl (32 kB)
# Using cached zstandard-0.25.0-cp313-cp313-win_amd64.whl (506 kB)
# Installing collected packages: filetype, zstandard, xxhash, websockets, uuid-utils, tenacity, sniffio, pyyaml, orjson, langchain-protocol, jsonpointer, distro, requests-toolbelt, jsonpatch, langsmith, langchain-core, google-genai, langchain-google-genai
# Successfully installed distro-1.9.0 filetype-1.2.0 google-genai-2.12.1 jsonpatch-1.33 jsonpointer-3.1.1 langchain-core-1.4.9 langchain-google-genai-4.2.7 langchain-protocol-0.0.18 langsmith-0.10.6 orjson-3.11.9 pyyaml-6.0.3 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 uuid-utils-0.17.0 websockets-16.1.1 xxhash-3.8.1 zstandard-0.25.0
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-3.5-flash")

response  = llm.invoke("Write a poem on college days.")

# %%
response
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'We walked through the gates with a hesitant stride,\nWith dreams in our pockets and checklists inside.\nThe campus felt endless, a bewildering maze,\nAnd so it began—our college days.\n\nRemember the lecture halls, chilly and bright,\nWhere we struggled to keep our heavy eyes light?\nThe notebooks we filled up with doodles and rhyme,\nAnd the watch that we stared at to hasten the time.\n\nBut sweeter by far was the sun on the lawn,\nThe endless debates from the dusk to the dawn.\nThe thrill of the bunk, the escape to the street,\nAnd the cheap cups of chai that made living feel sweet.\n\nIn the chaos of hostels, the midnight brigade,\nThrough instant noodles and plans we had made.\nWe’d cram for exams on a single night’s sleep,\nWith secrets and promises we swore we would keep.\n\nThe strangers we met on that very first day\nBecame the companions who showed us the way.\nWe stumbled, we fell, and we rose up again,\nLearning things that no textbook could ever explain.\n\nBut semesters flew like a breeze through the trees,\nTurning our moments to fast memories.\nAnd suddenly, there we were, standing in line,\nTo trade in our youth for a degree and a sign.\n\nNow the corridors echo with silence and dust,\nAnd our old group chats are beginning to rust.\nWe have scattered like leaves in the wind of the world,\nWith the sails of our destinies widely unfurled.\n\nYet sometimes a song or a scent in the air,\nTakes us right back to the quad over there.\nFor college was never just classes and grades—\nIt was the youth of our lives, and a light that never fades.', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f7a00-79e4-7433-8afa-2fc78f733044-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 1372, 'total_tokens': 1380, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 1006}})
