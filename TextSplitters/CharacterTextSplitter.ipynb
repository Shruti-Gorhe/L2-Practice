# %%
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader
# Out:
# [transformers] PyTorch was not found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# C:\Users\SG131245\AppData\Local\Temp\ipykernel_14176\3823926993.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("python programming.pdf")

docs = loader.load()

splitter = CharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap = 50,
    separator = " "
)

result = splitter.split_documents(docs)
print(result[10].page_content)
print(result[1].metadata)
# Out:
# . . . . . . . 67
# 6.2 Indentation . . . . . . . . . . . . . . . . . . . . . . . . . . . . 72
# 6.3 Truth, Falsehood and Logical Operators . . . . . . . . . . . . 72
# 6.4 if statement . . . . . . . . . . . . . . . . . . . . . . . . . . . 74
# 6.5 for loops . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 76
# 6.6 for loops and the range function . . . . . . . . . . . . . . . . 78
# 6.7 while loops . . . . . . . . . . . . . . . . . . . . . . . . . . . . 80
# 6.8 Control in Loops: break and continue .
# {'producer': 'pdfTeX-1.10b', 'creator': 'TeX', 'creationdate': 'D:20050316115600', 'source': 'python programming.pdf', 'total_pages': 164, 'page': 1, 'page_label': '2'}
